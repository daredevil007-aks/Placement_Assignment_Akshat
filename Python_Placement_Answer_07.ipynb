# %%
import pandas as pd
import seaborn as sns
import plotly as plt
df = pd.read_csv('metero.csv', parse_dates=['year'])
df
# Out:
#      Unnamed: 0       name     id nametype               recclass      mass  \
# 0             0     Aachen      1    Valid                     L5      21.0
# 1             1     Aarhus      2    Valid                     H6     720.0
# 2             2       Abee      6    Valid                    EH4  107000.0
# 3             3   Acapulco     10    Valid            Acapulcoite    1914.0
# 4             4    Achiras    370    Valid                     L6     780.0
# ..          ...        ...    ...      ...                    ...       ...
# 995         995   Tirupati  24009    Valid                     H6     230.0
# 996         996    Tissint  54823    Valid  Martian (shergottite)    7000.0
# 997         997      Tjabe  24011    Valid                     H6   20000.0
# 998         998   Tjerebon  24012    Valid                     L5   16500.0
# 999         999  Tomakovka  24019    Valid                    LL6     600.0
#
# ...

# %%
df['below_2000'] = df['year'] < '2000'   #taking below_2000 as new column which holds timeframe below 2000
true_values = df[df['below_2000'] == True]
true_values.name
sns.countplot(data=df, x='below_2000', color='purple')  #plotting it with seaborn
# Out:
# <AxesSubplot: xlabel='below_2000', ylabel='count'>

# %%
df['below_1970'] = df['year'] < '1970'    #taking below_1970 as new column which holds timeframe below 1970
true_value = df[df['below_1970'] == True]
true_value
sns.countplot(data=df, x='below_1970', color='purple') #plotting it with seaborn
# Out:
# <AxesSubplot: xlabel='below_1970', ylabel='count'>

# %%
df['mass_over'] = df['mass'] > 10000   #taking mass_over as new column which holds mass of above 10000
true_value = df[df['mass_over'] == True]
true_value.mass
# Out:
# 2      107000.0
# 7       30000.0
# 11      24000.0
# 16      50000.0
# 27     228000.0
#          ...
# 991     28000.0
# 992     74800.0
# 994     65500.0
# 997     20000.0
# 998     16500.0
# Name: mass, Length: 243, dtype: float64
